# %% [markdown]
# <a href="https://colab.research.google.com/github/cubrictiff/steel_defect_classification/blob/master/steel_ssd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed May  6 15:23:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    36W / 250W |   4771MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
! if ! test -d "/content/mydrive"; then ln -s "/content/drive/My Drive" "/content/mydrive"; fi

# %%
# !pip uninstall --quiet folium -y
# !pip install --quiet folium==0.2.1
# !pip install --quiet Pygments==2.5.1
# !pip install --quiet tensorflow-object-detection-api
# Out:
#      |████████████████████████████████| 71kB 2.1MB/s
# ...
#      |████████████████████████████████| 901kB 2.5MB/s
#      |████████████████████████████████| 583kB 2.8MB/s
#      |████████████████████████████████| 61kB 5.5MB/s
#      |████████████████████████████████| 2.7MB 12.0MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip uninstall --quiet kaggle -y
# !pip install --quiet --upgrade pip
# !pip install --quiet kaggle==1.5.6
# Out:
#      |████████████████████████████████| 1.5MB 2.6MB/s
#      |████████████████████████████████| 58 kB 260 kB/s
# ...

# %%
# !pip install --quiet Cython

# %% [markdown]
# Git clone

# %%
# !git clone https://github.com/tensorflow/models.git --quiet

# %%
# !find ./models -name "*.pyc" -exec rm {} \;

# %%
# !apt-get -qq install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 144429 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# ...

# %%
# %cd ./models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/models/research

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim'
# !python setup.py -q build
# !python setup.py -q install
# !python object_detection/builders/model_builder_test.py
# Out:
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.preprocessor.cpython-36: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-36: module MAY be using inspect.stack
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !mkdir -p /root/.kaggle
# !cp /content/drive/My\ Drive/kaggle.json /root/.kaggle/; chmod 600 /root/.kaggle/kaggle.json; kaggle competitions download -c severstal-steel-defect-detection
# !unzip -o -q severstal-steel-defect-detection.zip -d data
# Out:
# ...
#  99% 1.55G/1.57G [00:12<00:00, 162MB/s]
# 100% 1.57G/1.57G [00:12<00:00, 130MB/s]

# %%
# !cp /content/drive/My\ Drive/ssd/defect_labels.pbtxt defect_labels.pbtxt 
# !cp /content/drive/My\ Drive/ssd/ssd_mobilenet.config ssd_mobilenet.config

# %% [markdown]
# Generate Tfrecord

# %%
import tensorflow as tf
import os
import pandas as pd
from tqdm.notebook import tqdm
from io import BytesIO
import numpy as np
import contextlib2
from models.research.object_detection.utils import dataset_util
from models.research.object_detection.dataset_tools import tf_record_creation_util

# %%
class_df = pd.read_csv('mydrive/ssd/bbox_ssd_train.csv')
class_df
# Out:
#             filename  width  height  class    xmin   ymin    xmax   ymax
# 0      0002cc93b.jpg   1600     256    1.0   113.0   63.0   756.0  256.0
# 1      0007a71bf.jpg   1600     256    3.0    72.0    4.0  1168.0  256.0
# 2      000f6bf48.jpg   1600     256    4.0   515.0    0.0  1132.0  256.0
# 3      0014fce06.jpg   1600     256    3.0   896.0   60.0   930.0  250.0
# 4      0025bde0c.jpg   1600     256    3.0    33.0    2.0  1201.0  177.0
# ...              ...    ...     ...    ...     ...    ...     ...    ...
# 11683  fe2234ba6.jpg   1600     256    3.0   356.0  127.0   863.0  241.0
# 11684  ff6bfada2.jpg   1600     256    4.0   354.0   81.0  1050.0  256.0
# 11685  ff6e35e0a.jpg   1600     256    2.0  1484.0    0.0  1524.0  256.0
# 11686  db4867ee8.jpg   1600     256    3.0   913.0    0.0   926.0  256.0
# 11687  ef24da2ba.jpg   1600     256    3.0   696.0    1.0   722.0  256.0
#
# [11688 rows x 8 columns]

# %%
df_xmin = class_df.groupby('filename')['xmin'].apply(list).reset_index(name='new_xmin')
df_ymin = class_df.groupby('filename')['ymin'].apply(list).reset_index(name='new_ymin')
df_ymax = class_df.groupby('filename')['ymax'].apply(list).reset_index(name='new_ymax')
df_xmax = class_df.groupby('filename')['xmax'].apply(list).reset_index(name='new_xmax')
class_df['class'] = class_df['class'].fillna(0).astype(np.int64)
df_class = class_df.groupby('filename')['class'].apply(list).reset_index(name='new_class')

# %%
df1 = df_class.join(df_xmin['new_xmin'])
df2 = df1.join(df_ymin['new_ymin'])
df3 = df2.join(df_xmax['new_xmax'])
df4 = df3.join(df_ymax['new_ymax'])
df4
# Out:
#             filename new_class new_xmin new_ymin  new_xmax new_ymax
# 0      0002cc93b.jpg       [1]  [113.0]   [63.0]   [756.0]  [256.0]
# 1      00031f466.jpg       [0]    [nan]    [nan]     [nan]    [nan]
# 2      000418bfc.jpg       [0]    [nan]    [nan]     [nan]    [nan]
# 3      000789191.jpg       [0]    [nan]    [nan]     [nan]    [nan]
# 4      0007a71bf.jpg       [3]   [72.0]    [4.0]  [1168.0]  [256.0]
# ...              ...       ...      ...      ...       ...      ...
# 11341  fff0295e1.jpg       [0]    [nan]    [nan]     [nan]    [nan]
# 11342  fff02e9c5.jpg       [3]  [810.0]   [45.0]   [886.0]  [221.0]
# 11343  fffe98443.jpg       [3]  [413.0]  [170.0]   [466.0]  [236.0]
# 11344  ffff4eaa8.jpg       [3]   [66.0]    [1.0]   [592.0]  [256.0]
# 11345  ffffd67df.jpg       [3]  [120.0]    [0.0]   [143.0]  [254.0]
#
# [11346 rows x 6 columns]

# %%
data_dir = os.getcwd()
train_dir = os.path.join("/content/data/train_images")
from PIL import Image
debug = False
def create_tf_example(filename, _xmins, _xmaxs, _ymins, _ymaxs, _classes):
    height = 256 # Image height
    width = 1600 # Image width

    path = os.path.join(train_dir, filename)

    filenameSplit = filename.split('.')[0]
    
    with tf.gfile.GFile(os.path.join(train_dir, '{}'.format(filename)), 'rb') as fid:
        encoded_image_data = fid.read()
    
    image = Image.open(path)
    

    filename = filenameSplit.encode('utf8')
    image_format = b'jpeg' # b'jpeg' or b'png'


    xmins = [] # List of normalized left x coordinates in bounding box (1 per box)
    xmaxs = [] # List of normalized right x coordinates in bounding box
                # (1 per box)
    ymins = [] # List of normalized top y coordinates in bounding box (1 per box)
    ymaxs = [] # List of normalized bottom y coordinates in bounding box
                # (1 per box)

    classes_text = [] # List of string class name of bounding box (1 per box)
    classes = [] # List of integer class id of bounding box (1 per box)

    def norm_xbox(xlst):
      n_lst =[]
      for i in xlst:
        i /= 1600
        n_lst.append(i)
      return n_lst
    def norm_ybox(ylst):
      n_lst = []
      for i in ylst:
        i /= 256
        n_lst.append(i)
      return n_lst
    
    if not np.isnan(_xmins).any():
      xmins = norm_xbox(_xmins)
      xmaxs = norm_xbox(_xmaxs)
      ymins = norm_ybox(_ymins)
      ymaxs = norm_ybox(_ymaxs)
      classes = _classes

      def binary_list(_classes):
        if _classes == 1:
          return(b'1')
        elif  _classes == 2:
          return(b'2')
        elif  _classes == 3:
          return(b'3')
        else:
          return(b'4')

      classes_text = [binary_list(x) for x in classes]
      

    if (debug):
        print(xmins)
        print(xmaxs)
        print(ymins)
        print(ymaxs)
        print(classes)
    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_image_data),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text), #bytes_list_feature
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

# %%
num_shards=10
output_filebase='train'

with contextlib2.ExitStack() as tf_record_close_stack:
    output_tfrecords = tf_record_creation_util.open_sharded_output_tfrecords(
        tf_record_close_stack, output_filebase, num_shards)

    
    count = 0

    for idx, (filename, new_class, new_xmin, new_ymin, new_xmax, new_ymax) in tqdm(df4.iterrows()):
        tf_example = create_tf_example(filename=filename, 
                        _xmins=new_xmin, 
                        _xmaxs=new_xmax, 
                        _ymins=new_ymin, 
                        _ymaxs=new_ymax, 
                        _classes=new_class) 

        output_shard_index = count % num_shards
        output_tfrecords[output_shard_index].write(tf_example.SerializeToString())

        count += 1

# %% [markdown]
# test TF record

# %%
test_df = pd.read_csv('mydrive/ssd/bbox_ssd_test.csv')
df_xmin2 = test_df.groupby('filename')['xmin'].apply(list).reset_index(name='new_xmin')
df_ymin2 = test_df.groupby('filename')['ymin'].apply(list).reset_index(name='new_ymin')
df_ymax2 = test_df.groupby('filename')['ymax'].apply(list).reset_index(name='new_ymax')
df_xmax2 = test_df.groupby('filename')['xmax'].apply(list).reset_index(name='new_xmax')
test_df['class'] = class_df['class'].fillna(0).astype(np.int64)
df_test = test_df.groupby('filename')['class'].apply(list).reset_index(name='new_class')
df5 = df_test.join(df_xmin2['new_xmin'])
df6 = df5.join(df_ymin2['new_ymin'])
df7 = df6.join(df_xmax2['new_xmax'])
df8 = df7.join(df_ymax2['new_ymax'])
df8
# Out:
#            filename new_class  new_xmin new_ymin  new_xmax new_ymax
# 0     000a4bcdd.jpg       [1]   [146.0]   [55.0]   [462.0]  [256.0]
# 1     005f02e20.jpg       [3]  [1244.0]  [104.0]  [1297.0]  [215.0]
# 2     00af2671f.jpg       [4]   [607.0]    [0.0]  [1121.0]  [256.0]
# 3     012d29df4.jpg       [3]     [0.0]   [29.0]  [1421.0]  [249.0]
# 4     015ed7fac.jpg       [3]     [nan]    [nan]     [nan]    [nan]
# ...             ...       ...       ...      ...       ...      ...
# 1299  fef40d085.jpg       [3]     [nan]    [nan]     [nan]    [nan]
# 1300  ff09babee.jpg       [3]     [nan]    [nan]     [nan]    [nan]
# 1301  ff4ddccf9.jpg       [2]   [355.0]    [0.0]  [1296.0]  [256.0]
# 1302  ffa8210a1.jpg       [3]     [nan]    [nan]     [nan]    [nan]
# 1303  ffb48ee43.jpg       [3]   [151.0]    [0.0]  [1600.0]  [256.0]
#
# [1304 rows x 6 columns]

# %%
num_shards=1
output_filebase='test'

with contextlib2.ExitStack() as tf_record_close_stack:
    output_tfrecords = tf_record_creation_util.open_sharded_output_tfrecords(
        tf_record_close_stack, output_filebase, num_shards)

    
    count = 0

    for idx, (filename, new_class, new_xmin, new_ymin, new_xmax, new_ymax) in tqdm(df8.iterrows()):
        tf_example = create_tf_example(filename=filename, 
                        _xmins=new_xmin, 
                        _xmaxs=new_xmax, 
                        _ymins=new_ymin, 
                        _ymaxs=new_ymax, 
                        _classes=new_class) 

        output_shard_index = count % num_shards
        output_tfrecords[output_shard_index].write(tf_example.SerializeToString())

        count += 1
# Out:
# WARNING:tensorflow:From /content/models/research/object_detection/dataset_tools/tf_record_creation_util.py:43: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
# ...

# %%
# !wget http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2018_01_28.tar.gz
# !tar -xvzf  ssd_inception_v2_coco_2018_01_28.tar.gz; rm ssd_inception_v2_coco_2018_01_28.tar.gz
# Out:
# --2020-05-06 05:36:53--  http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2018_01_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.140.128, 2a00:1450:400c:c08::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.140.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278114232 (265M) [application/x-tar]
# Saving to: ‘ssd_inception_v2_coco_2018_01_28.tar.gz’
#
# ssd_inception_v2_co 100%[===================>] 265.23M  89.2MB/s    in 3.0s
#
# 2020-05-06 05:36:57 (89.2 MB/s) - ‘ssd_inception_v2_coco_2018_01_28.tar.gz’ saved [278114232/278114232]
#
# ssd_inception_v2_coco_2018_01_28/
# ssd_inception_v2_coco_2018_01_28/model.ckpt.index
# ssd_inception_v2_coco_2018_01_28/checkpoint
# ssd_inception_v2_coco_2018_01_28/pipeline.config
# ssd_inception_v2_coco_2018_01_28/model.ckpt.data-00000-of-00001
# ssd_inception_v2_coco_2018_01_28/model.ckpt.meta
# ...

# %%
# !cp /content/models/research/object_detection/legacy/train.py ./train.py
# !cp /content/drive/My\ Drive/ssd/ssd_mobilenet.config ssd_mobilenet.config
# !python ./train.py   --train_dir=/content/mydrive/ssd/logs --pipeline_config_path=ssd_mobilenet.config --logtostderr

# %% [markdown]
# Evaluation

# %%
# !cp /content/models/research/object_detection/legacy/eval.py ./eval.py

# %%
# !python eval.py --logtostderr --pipeline_config_path=ssd_mobilenet.config --checkpoint_dir=/content/mydrive/ssd/logs --eval_dir=/content/mydrive/ssd/logs
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:57: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From eval.py:57: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From eval.py:143: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/absl/app.py:250: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !cd /content/models/research/object_detection; \
python export_inference_graph.py --input_type image_tensor \
        --pipeline_config_path /content/ssd_mobilenet.config \
        --trained_checkpoint_prefix /content/mydrive/ssd/logs/model.ckpt-146185 \
        --output_directory /content/mydrive/ssd/logs/inference_graph;
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0506 12:10:25.178984 140205642995584 module_wrapper.py:139] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
from models.research.object_detection.utils import label_map_util
from models.research.object_detection.utils import visualization_utils as vis_util
import glob

# %%
import glob
import shutil
import os

src_dir = "/content/data/train_images"
dst_dir = "/content/test"
for i in range(len(df_test['filename'])):
  image = df_test['filename'][i]
  jpgfile = os.path.join(src_dir, str(image))
  shutil.copy(jpgfile, dst_dir)

# %%
frozen_inference_graph_path = '/content/mydrive/ssd/logs/inference_graph/frozen_inference_graph.pb'
labelmap_path = '/content/mydrive/ssd/defect_labels.pbtxt'
test_img_path = glob.glob('/content/test/*.jpg')

# %%
label_map = label_map_util.load_labelmap(labelmap_path)
categories = label_map_util.convert_label_map_to_categories(label_map, 
                                                            max_num_classes=4, 
                                                            use_display_name=True)
category_index = label_map_util.create_category_index(categories)
# Out:
# WARNING:tensorflow:From /content/models/research/object_detection/utils/label_map_util.py:138: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(frozen_inference_graph_path, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

    sess = tf.Session(graph=detection_graph)

# %%
# Define input and output tensors (i.e. data) for the object detection classifier

# Input tensor is the image
image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')

# Output tensors are the detection boxes, scores, and classes
# Each box represents a part of the image where a particular object was detected
detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')

# Each score represents level of confidence for each of the objects.
# The score is shown on the result image, together with the class label.
detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
# Number of objects detected
num_detections = detection_graph.get_tensor_by_name('num_detections:0')

# %%
import collections

STANDARD_COLORS = [
    'AliceBlue', 'Chartreuse', 'Aqua', 'Aquamarine', 'Azure', 'Beige', 'Bisque',
    'BlanchedAlmond', 'BlueViolet', 'BurlyWood', 'CadetBlue', 'AntiqueWhite',
    'Chocolate', 'Coral', 'CornflowerBlue', 'Cornsilk', 'Crimson', 'Cyan',
    'DarkCyan', 'DarkGoldenRod', 'DarkGrey', 'DarkKhaki', 'DarkOrange',
    'DarkOrchid', 'DarkSalmon', 'DarkSeaGreen', 'DarkTurquoise', 'DarkViolet',
    'DeepPink', 'DeepSkyBlue', 'DodgerBlue', 'FireBrick', 'FloralWhite',
    'ForestGreen', 'Fuchsia', 'Gainsboro', 'GhostWhite', 'Gold', 'GoldenRod',
    'Salmon', 'Tan', 'HoneyDew', 'HotPink', 'IndianRed', 'Ivory', 'Khaki',
    'Lavender', 'LavenderBlush', 'LawnGreen', 'LemonChiffon', 'LightBlue',
    'LightCoral', 'LightCyan', 'LightGoldenRodYellow', 'LightGray', 'LightGrey',
    'LightGreen', 'LightPink', 'LightSalmon', 'LightSeaGreen', 'LightSkyBlue',
    'LightSlateGray', 'LightSlateGrey', 'LightSteelBlue', 'LightYellow', 'Lime',
    'LimeGreen', 'Linen', 'Magenta', 'MediumAquaMarine', 'MediumOrchid',
    'MediumPurple', 'MediumSeaGreen', 'MediumSlateBlue', 'MediumSpringGreen',
    'MediumTurquoise', 'MediumVioletRed', 'MintCream', 'MistyRose', 'Moccasin',
    'NavajoWhite', 'OldLace', 'Olive', 'OliveDrab', 'Orange', 'OrangeRed',
    'Orchid', 'PaleGoldenRod', 'PaleGreen', 'PaleTurquoise', 'PaleVioletRed',
    'PapayaWhip', 'PeachPuff', 'Peru', 'Pink', 'Plum', 'PowderBlue', 'Purple',
    'Red', 'RosyBrown', 'RoyalBlue', 'SaddleBrown', 'Green', 'SandyBrown',
    'SeaGreen', 'SeaShell', 'Sienna', 'Silver', 'SkyBlue', 'SlateBlue',
    'SlateGray', 'SlateGrey', 'Snow', 'SpringGreen', 'SteelBlue', 'GreenYellow',
    'Teal', 'Thistle', 'Tomato', 'Turquoise', 'Violet', 'Wheat', 'White',
    'WhiteSmoke', 'Yellow', 'YellowGreen'
]

""
"-------------KAGGLE COORDINATES & SCORES"
""
def return_kaggle_coordinates_scores(
    image,
    boxes,
    classes,
    scores,
    category_index,
    instance_masks=None,
    instance_boundaries=None,
    keypoints=None,
    use_normalized_coordinates=False, 
    max_boxes_to_draw=20,
    min_score_thresh=.5,
    agnostic_mode=False,
    line_thickness=4,
    groundtruth_box_visualization_color='black',
    skip_scores=False,
    skip_labels=False):
  # Create a display string (and color) for every box location, group any boxes
  # that correspond to the same location.
  box_to_display_str_map = collections.defaultdict(list)
  box_to_color_map = collections.defaultdict(str)
  box_to_instance_masks_map = {}
  box_to_instance_boundaries_map = {}
  box_to_score_map = {}
  box_to_keypoints_map = collections.defaultdict(list)
  if not max_boxes_to_draw:
    max_boxes_to_draw = boxes.shape[0]
  for i in range(min(max_boxes_to_draw, boxes.shape[0])):
    if scores is None or scores[i] > min_score_thresh:
      box = tuple(boxes[i].tolist())
      if instance_masks is not None:
        box_to_instance_masks_map[box] = instance_masks[i]
      if instance_boundaries is not None:
        box_to_instance_boundaries_map[box] = instance_boundaries[i]
      if keypoints is not None:
        box_to_keypoints_map[box].extend(keypoints[i])
      if scores is None:
        box_to_color_map[box] = groundtruth_box_visualization_color
      else:
        display_str = ''
        if not skip_labels:
          if not agnostic_mode:
            if classes[i] in category_index.keys():
              class_name = category_index[classes[i]]['name']
            else:
              class_name = 'N/A'
            display_str = str(class_name)
        if not skip_scores:
          if not display_str:
            display_str = '{}%'.format(int(100*scores[i]))
          else:
            display_str = '{}: {}%'.format(display_str, int(100*scores[i]))
        box_to_display_str_map[box].append(display_str)
        box_to_score_map[box] = scores[i]
        if agnostic_mode:
          box_to_color_map[box] = 'DarkOrange'
        else:
          box_to_color_map[box] = STANDARD_COLORS[
              classes[i] % len(STANDARD_COLORS)]

  # Draw all boxes onto image.
  score_coor_list = []
  counter_for = 0 
  for box,color in box_to_color_map.items():
    ymin, xmin, ymax, xmax = box
    height, width, channels = image.shape
    ymin = int(ymin*height)  
    ymax = int(ymax*height)
    xmin = int(xmin*width)
    xmax = int(xmax*width)
    score_coor_list.append([class_name, box_to_score_map[box], xmin, ymin, xmax, ymax])
    counter_for = counter_for + 1
    
    

  return score_coor_list

# %%
kaggle_columns = ['ImageId','class','confidence','xmin', 'ymin', 'xmax', 'ymax']
kaggle_m1 = pd.DataFrame(columns = kaggle_columns)
Kaggle_job_counter = 0

new_size_m1 = 0.5
score_threshold_m1 = 0.5


import cv2
############################ Start the Loop: Each image draw and get coordinates for Kaggle and ZFTurbo ###############################################3

for image_path in tqdm(test_img_path[1:]):
    image = cv2.imread(image_path)
    image_expanded = np.expand_dims(image, axis=0)

    filename = image_path.split("test/",1)[1]   # 4 pictures, this set is visual only
    
    
    
    (boxes, scores, classes, num) = sess.run(
    [detection_boxes, detection_scores, detection_classes, num_detections],
    feed_dict={image_tensor: image_expanded})
    score_coor = return_kaggle_coordinates_scores(
        image,
        np.squeeze(boxes),
        np.squeeze(classes).astype(np.int32),
        np.squeeze(scores),
        category_index,
        use_normalized_coordinates=True,
        line_thickness=8,
        min_score_thresh = score_threshold_m1)
    
    if score_coor != []:
        tmp = pd.DataFrame(np.array(score_coor),
                             columns=['class','confidence','xmin', 'ymin', 'xmax', 'ymax'])
        tmp['ImageId'] = filename
        tmp = tmp[['ImageId','class','confidence','xmin', 'ymin', 'xmax', 'ymax']]
  

        # resize the bounding box to see if it improve precision
        tmp['xmax'] = tmp['xmax'].astype(int)        
        tmp['ymax'] = tmp['ymax'].astype(int)
        tmp['xmin'] = tmp['xmin'].astype(int)
        tmp['ymin'] = tmp['ymin'].astype(int)
        
        
        #width = tmp['xmax'] - tmp['xmin']
        #height = tmp['ymax'] - tmp['ymin']

        #xAdjust = width*(1-new_size_m1)/2 # find the change in width
        #yAdjust = height*(1-new_size_m1)/2 
        #tmp['xmin'] = tmp['xmin'] + xAdjust
        #tmp['ymin'] = tmp['ymin'] + yAdjust
        #tmp['xmax'] = tmp['xmax'] - xAdjust
        #tmp['ymax'] = tmp['ymax'] - yAdjust
        

    else :
        tmp = pd.DataFrame(columns = ['ImageId','class','confidence','xmin', 'ymin', 'xmax', 'ymax'])
        tmp = tmp.append({'ImageId': filename, 'class':'', 'confidence':'', 'xmin': '', 'ymin': '', 'xmax': '', 'ymax': ''}, ignore_index=True)
    kaggle_m1 = kaggle_m1.append(tmp)

# %%
kaggle_m1.head(20)
# Out:
#          ImageId class  confidence    xmin   ymin     xmax    ymax
# 0  dbe255803.jpg     3   0.8311175  270.75  66.25   792.25  192.75
# 0  45ebf8adb.jpg
# 0  d0ba35b7f.jpg
# 0  badd96385.jpg
# 0  3a619ce77.jpg
# 0  65cdc6528.jpg
# 0  ad3630cdc.jpg
# 0  b68b3a262.jpg
# 0  a0ce98154.jpg
# 0  533261093.jpg
# 0  0cb3064bd.jpg     3  0.66574407  534.75  66.25   918.25  192.75
# 0  9150a0950.jpg     3   0.9387168  499.25   64.5  1181.75   189.5
# 0  adaa47142.jpg
# 0  8355a5249.jpg
# 0  05431e2d2.jpg     3  0.61689496   374.5  63.75    801.5  191.25
# 0  d51a45df9.jpg
# 0  b9fc6b359.jpg
# 0  f35093ccb.jpg
# 0  c319a0d11.jpg
# 0  2d3c47b87.jpg

# %%
kaggle_m1.to_csv('mydrive/ssd/predict_bbox.csv')
